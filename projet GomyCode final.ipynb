# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <center>
# Parce que KNN est basé sur la similitude des caractéristiques, nous pouvons effectuer une classification à l'aide de KNN Classifier !
# </center>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <center>
# KNN - K Nearest Neighbors, est l'un des algorithmes d'apprentissage automatique supervisé les plus simples, principalement utilisé pour classification.
#
# Il classe un point de données en fonction de la façon dont ses voisins sont classés.
#
# KNN stocke tous les cas disponibles et classe les nouveaux cas en fonction d'une mesure de similarité.<br>
# </center>
# <h1><i>Mais qu'est-ce que K ?</i></h1>
# <center>k dans KNN est un paramètre qui fait référence au nombre de voisins les plus proches à inclure dans le processus de vote à la majorité.
# si k = 5 Un point de données est classé par les votes majoritaires de ses 5 plus proches voisins.
# </center>

# %% [markdown]
# <table>
#   <tr>
#     <td><h1>Ici, le point inconnu serait classé<br>
#      en rouge, puisque 4 voisins sur 5<br> sont rouges<h1></td>
#     <td>
#
# ![image.png](data:image/png;base64,...)
#
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <center>L'algorithme KNN est basé sur la similarité des caractéristiques : le choix de la bonne valeur de k est un processus appelé réglage des paramètres et est important pour une meilleure précision</center>
# <h1>Pour choisir une valeur de k :</h1>
# <h3>
# 1. Sqrt(n), où n est le nombre total de points de données</h3>
# <h3>
# 2. La valeur impaire de K est sélectionnée pour éviter toute confusion entre deux classes de données<h3>
# <center><h1>Une valeur plus élevée de k a moins de chance d'erreur</h1></center>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h3>
# 1. Les données sont étiquetées<br>
# 2. les données sont sans bruit<br>
# 3. L'ensemble de données est petit, car KNN est un « apprenant paresseux », c'est-à-dire qu'il n'apprend pas de fonction discriminante à partir de l'ensemble d'apprentissage
# </h3>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <center>Considérons un ensemble de données ayant deux variables : la taille (cm) et le poids (kg) et chaque point est classé comme normal ou underweight:
# </center>
# <table>
#   <tr>
#     <th>weight(x2)</th>
#     <th>height(y2)</th>
#     <th>class</th>
#   </tr>
#   <tr>
#     <td>51</td>
#     <td>167</td>
#     <td>underweight</td>
#  </tr>
#    <tr>
#     <td>62</td>
#     <td>182</td>
#     <td>normal</td>
#   </tr>
#   <tr>
#     <td>69</td>
#     <td>176</td>
#     <td>normal</td>
#  </tr>
#    <tr>
#     <td>64</td>
#     <td>173</td>
#     <td>normal</td>
#   </tr>
#   <tr>
#     <td>65</td>
#     <td>172</td>
#     <td>normal</td>
#  </tr>
#    <tr>
#     <td>56</td>
#     <td>174</td>
#     <td>underweight</td>
#   </tr>
#   <tr>
#     <td>58</td>
#     <td>169</td>
#     <td>normal</td>
#  </tr>
#    <tr>
#     <td>57</td>
#     <td>173</td>
#     <td>normal</td>
#   </tr>
#   <tr>
#     <td>55</td>
#     <td>170</td>
#     <td>normal</td>
#  </tr>
# </table>

# %% [markdown]
# <center>nous devons classer l'ensemble ci-dessous comme normal ou insuffisant à l'aide de KNN
# </center>
# <table>
# <tr><th>57 KG<th><th>170 cm</th><th>?</th></table>
# <center>
# <h1>En supposant que nous ne sachions pas comment calculer l'IMC  (indice de masse corporelle) !</h1>
# </center>
# Pour trouver les voisins les plus proches, nous allons calculer la distance euclidienne, la distance euclidienne entre deux points du plan de coordonnées (x, y) et (a, b) est donnée par :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# nous calculerons la distance euclidienne d'un point de données inconnu à partir de tous les points de l'ensemble de données
#
# <h1>exemple:</h1> calcule distance entre le poin(172,51) et tout les autre points:
# </center>
# <table>
# <tr><th>57 KG<th><th>170 cm</th><th>?</th></table>
# <center>
# <h1>En supposant que nous ne sachions pas comment calculer l'IMC  (indice de masse corporelle) !</h1>
# </center>
# <br>
#
# <table>
#   <tr>
#     <th>weight(x2)</th>
#     <th>height(y2)</th>
#     <th>class</th>
#     <th>Eclidean distance</th>
#   </tr>
#   <tr>
#     <td>51</td>
#     <td>167</td>
#     <td>underweight</td>
#     <td>7.6<td>
#  </tr>
#    <tr>
#     <td>62</td>
#     <td>182</td>
#     <td>normal</td>
#     <td>13<td>
#   </tr>
#   <tr>
#     <td>69</td>
#     <td>176</td>
#     <td>normal</td>
#     <td>13.4<td>
#  </tr>
#    <tr>
#     <td>64</td>
#     <td>173</td>
#     <td>normal</td>
#     <td>7.6<td>
#   </tr>
#   <tr>
#     <td>65</td>
#     <td>172</td>
#     <td>normal</td>
#     <td>8.2<td>
#  </tr>
#    <tr>
#     <td>56</td>
#     <td>174</td>
#     <td>underweight</td>
#     <td>4.1<td>
#   </tr>
#   <tr>
#     <td>58</td>
#     <td>169</td>
#     <td>normal</td>
#     <td>1.4<td>
#  </tr>
#    <tr>
#     <td>57</td>
#     <td>173</td>
#     <td>normal</td>
#     <td>3<td>
#   </tr>
#   <tr>
#     <td>55</td>
#     <td>170</td>
#     <td>normal</td>
#     <td>2<td>
#  </tr>
# </table>

# %% [markdown]
# <h1>Maintenant, calculons le voisin le plus proche  k=3:</h1>
# Nous avons n=10, Et sqrt(10)=3.1 Par conséquent, nous avons pris k=3
# <table>
#   <tr>
#     <td>58</td>
#     <td>169</td>
#     <td>normal</td>
#     <td>1.4<td>
#  </tr>
#    <tr>
#     <td>57</td>
#     <td>173</td>
#     <td>normal</td>
#     <td>3<td>
#   </tr>
#   <tr>
#     <td>55</td>
#     <td>170</td>
#     <td>normal</td>
#     <td>2<td>
#  </tr>
# </table>
# <br>
# <fieldset>
#     <legend ALIGN="center"><fieldset>conséquent</fieldset></legend>
# les voisins majoritaires pointent vers « Normal »
# Par conséquent, selon l'algorithme KNN, la classe de (57, 170) devrait être « Normal »
# </fieldset>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <fieldset>
# Classification des types d'étoiles :<br>
# Pour comparer tous les modèles de ML Il peut être utilisé pour la prédiction<br>
# * Temperature -- K
# * L -- L/Lo
# * R -- R/Ro
# * AM -- Mv
# * Color -- Couleur générale du spectre
# * Spectral_Class -- O,B,A,F,G,K,M / SMASS - https://en.wikipedia.org/wiki/Asteroid_spectral_types
# * Type -- Naine rouge, naine brune, naine blanche, séquence principale, super géants, hyper géants
# <center>
# <h1>
# TARGET: Type
# </h1>
# </center>
# de 0 à 5: <br>
# * Naine rouge - 0
# * Naine brune - 1
# * Naine Blanche - 2
# * Séquence principale - 3
# * Super Géants - 4
# * Hyper géants - 5
#
# MATH:
#
# Lo = 3,828 x 10^26 watts
# (Luminosité moyenne du soleil)
# Ro = 6,9551 x 10^8 m
# (Rayon moyen du soleil)
# </fieldset>

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

#importer les bib machin learning
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
nom_file ="start"
data = pd.read_csv(nom_file + ".txt")
data
# Out:
#      Temperature              L          R    A_M  Color Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12    Red              M     0
# 1           3042       0.000500     0.1542  16.60    Red              M     0
# 2           2600       0.000300     0.1020  18.70    Red              M     0
# 3           2800       0.000200     0.1600  16.65    Red              M     0
# 4           1939       0.000138     0.1030  20.06    Red              M     0
# ..           ...            ...        ...    ...    ...            ...   ...
# 235        38940  374830.000000  1356.0000  -9.93   Blue              O     5
# 236        30839  834042.000000  1194.0000 -10.63   Blue              O     5
# 237         8829  537493.000000  1423.0000 -10.73  White              A     5
# 238         9235  404940.000000  1112.0000 -11.23  White              A     5
# 239        37882  294903.000000  1783.0000  -7.80   Blue              O     5
#
# [240 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# 3068      0
# 0.0024    0
# 0.17      0
# 16.12     0
# Red       0
# M         0
# 0         0
# dtype: int64

# %%
Temperature = data.iloc[:,0]
L =data.iloc[:,1]
R = data.iloc[:,2]
A_M = data.iloc[:,3]
Color = data.iloc[:,4]
Spectral_Class = data.iloc[:,5]
Type = data.iloc[:,6]


#sns.pairplot(data[["radius_mean", "texture_mean", "perimeter_mean", "area_mean", "smoothness_mean", "compactness_mean", "diagnosis"]], hue='diagnosis')
#df = pd.DataFrame({'Temperature':Temperature, 'L':L,'R':R, 'A_M':A_M, 'Color':Color, 'Spectral_Class':Spectral_Class, 'Type':Type})
#sns.pairplot(df[['Temperature','L','R','A_M','Color','Spectral_Class','Type']], hue='Type')

# %% [markdown]
# fonction d'encodeur d'étiquette<br><br>
# "Color":{'Red':1, 'Blue White':2, 'White':3, 'Yellowish White':4, 'Blue white':5, 'Pale yellow orange':6, 'Blue':7, 'Blue-white':8, 'Whitish':9,'yellow-white':10, 'Orange':11,'White-Yellow':12,'white':13, 'yellowish':14, 'Yellowish':15, 'Orange-Red':16, 'Blue-White':17}<br>
# <br>
# "Spectral_Class":{'M':1, 'B':2, 'A':3, 'F':4, 'O':5, 'K':6, 'G':7}

# %%
#color
l = []
i=0
for x in (data.iloc[:,4]):
  if x not in l:
    l.append(x)
    i =i+1
print(l)
print("nbr de val =",i)
# Out:
# ['Red', 'Blue White', 'White', 'Yellowish White', 'Blue white', 'Pale yellow orange', 'Blue', 'Blue-white', 'Whitish', 'yellow-white', 'Orange', 'White-Yellow', 'white', 'yellowish', 'Yellowish', 'Orange-Red', 'Blue-White']
# nbr de val = 17

# %%
#colon
cleanup_nums = {
    "Color":{'Red':1, 'Blue White':2, 'White':3, 'Yellowish White':4, 'Blue white':5, 'Pale yellow orange':6, 'Blue':7, 'Blue-white':8, 'Whitish':9, 'yellow-white':10, 'Orange':11, 'White-Yellow':12,
             'white':13, 'yellowish':14, 'Yellowish':15, 'Orange-Red':16, 'Blue-White':17}}
data.replace(cleanup_nums, inplace=True)
data
# Out:
#      Temperature              L          R    A_M  Color Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12      1              M     0
# 1           3042       0.000500     0.1542  16.60      1              M     0
# 2           2600       0.000300     0.1020  18.70      1              M     0
# 3           2800       0.000200     0.1600  16.65      1              M     0
# 4           1939       0.000138     0.1030  20.06      1              M     0
# ..           ...            ...        ...    ...    ...            ...   ...
# 235        38940  374830.000000  1356.0000  -9.93      7              O     5
# 236        30839  834042.000000  1194.0000 -10.63      7              O     5
# 237         8829  537493.000000  1423.0000 -10.73      3              A     5
# 238         9235  404940.000000  1112.0000 -11.23      3              A     5
# 239        37882  294903.000000  1783.0000  -7.80      7              O     5
#
# [240 rows x 7 columns]

# %%
#Spectral_Class
l = []
i=0
for x in (data.iloc[:,5]):
  if x not in l:
    l.append(x)
    i =i+1
print(l)
print("nbr de val =",i)
# Out:
# ['M', 'B', 'A', 'F', 'O', 'K', 'G']
# nbr de val = 7

# %%
cleanup_nums = {"Spectral_Class":{'M':1, 'B':2, 'A':3, 'F':4, 'O':5, 'K':6, 'G':7}}
data.replace(cleanup_nums,inplace=True)
data
# Out:
#      Temperature              L          R    A_M  Color  Spectral_Class  Type
# 0           3068       0.002400     0.1700  16.12      1               1     0
# 1           3042       0.000500     0.1542  16.60      1               1     0
# 2           2600       0.000300     0.1020  18.70      1               1     0
# 3           2800       0.000200     0.1600  16.65      1               1     0
# 4           1939       0.000138     0.1030  20.06      1               1     0
# ..           ...            ...        ...    ...    ...             ...   ...
# 235        38940  374830.000000  1356.0000  -9.93      7               5     5
# 236        30839  834042.000000  1194.0000 -10.63      7               5     5
# 237         8829  537493.000000  1423.0000 -10.73      3               3     5
# 238         9235  404940.000000  1112.0000 -11.23      3               3     5
# 239        37882  294903.000000  1783.0000  -7.80      7               5     5
#
# [240 rows x 7 columns]

# %%
import csv
import random
import math
import operator

# calculating the dstance between the points multidimansional
def euclideanDistance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x]-instance2[x]), 2)
    return math.sqrt(distance)
 
# get k neighbors
def getNeighbors(trainingSet, testInstance, k):
    distances = []
    length = len(testInstance)-1 # -1  car la dernière colomn  n'est pas un dimension c'est un nome de fleur
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x], length)
        distances.append((trainingSet[x], dist))   #get the distance from the test point to other points
    distances.sort(key=operator.itemgetter(1))    # Sort all distances
    neighbors = []
    for x in range(k):   #get the k nearest
      neighbors.append(distances[x][0])
    return neighbors
 

# get the most class of the k neighbors
def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][-1]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]   #Get the category with the most vote





def getAccuracy(testSet, predictions):
  correct = 0
  for x in range(len(testSet)):
    if testSet[x][-1] == predictions[x]:
      correct += 1
  return (correct/float(len(testSet)))*100.0
 


def main():
    #prepare data
    trainingSet = []
    testSet = []
    dataset =[]
    split= 0.67
    for i, r in data.iterrows():
      mylist=[r.Temperature,r.L,r.R, r.A_M, r.Color, r.Spectral_Class, r.Type]
      dataset.append(mylist)
    #print(dataset[0][1])
    for x in range(len(dataset)-1):
      for y in range(6):
        dataset[x][y] = float(dataset[x][y])
      if random.random() < split:
        trainingSet.append(dataset[x])
      else:
        testSet.append(dataset[x])
    print('Trainset: ' + repr(len(trainingSet)))
    print('Testset: ' + repr(len(testSet)))
 #generate predictions
    predictions = []
    k = 3
    for x in range(len(testSet)):
        # trainingset trainingSet[x]
        neighbors = getNeighbors(trainingSet, testSet[x], k)# neighbors liste contient les k plus proche point (tester un instane de test avec tout ls données d'entrainement)
        result = getResponse(neighbors) # result contient la catégorie avec le plus de votes de type de fleur
        predictions.append(result)
        print ('predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1])) # comparaison entre la valeur prédite pour une instance de test et sa valeur réelle. 
    print('predictions: ' + repr(predictions))
    print("taill perdi=",len(predictions)," tiall de données de test", len(testSet)) # taill de données de test est la meme taill de deonnées de presiction
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%') # afficher Précision en pourcentage


if __name__ == '__main__':
    main()
# Out:
# Trainset: 154
# Testset: 85
# predicted=1.0, actual=0.0
# predicted=0.0, actual=0.0
# predicted=0.0, actual=0.0
# predicted=0.0, actual=0.0
# predicted=0.0, actual=0.0
# predicted=0.0, actual=1.0
# predicted=2.0, actual=2.0
# predicted=2.0, actual=2.0
# predicted=2.0, actual=2.0
# predicted=3.0, actual=2.0
# predicted=3.0, actual=3.0
# predicted=3.0, actual=3.0
# predicted=2.0, actual=3.0
# predicted=3.0, actual=3.0
# predicted=4.0, actual=4.0
# predicted=4.0, actual=4.0
# predicted=5.0, actual=4.0
# predicted=4.0, actual=4.0
# predicted=5.0, actual=5.0
# predicted=5.0, actual=5.0
# predicted=4.0, actual=5.0
# predicted=4.0, actual=5.0
# predicted=4.0, actual=5.0
# predicted=4.0, actual=5.0
# predicted=0.0, actual=0.0
# predicted=0.0, actual=0.0
# predicted=0.0, actual=0.0
# predicted=0.0, actual=0.0
# predicted=1.0, actual=1.0
# predicted=1.0, actual=1.0
# predicted=0.0, actual=1.0
# predicted=0.0, actual=1.0
# predicted=2.0, actual=2.0
# predicted=2.0, actual=2.0
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Un entier positif k est spécifié, ainsi qu'un nouvel échantillon
# * Nous sélectionnons les k entrées dans notre base de données qui sont les plus proches du nouvel échantillon
#
# * Nous trouvons la classification la plus courante de ces entrées
#
# * C'est la classification que nous donnons au nouvel échantillon

# %% [markdown]
# <h1> lien de données</h1>
# https://www.kaggle.com/brsdincer/star-type-classification
